# %%
import pandas as pd
plebiscito = pd.read_excel("/home/sebastian/Insync/lshuneeus@uc.cl/Google Drive/curso analisis datos politicos 2020/ayudantias shuneeus/bases_ayudantias/bd_plebiscito.xlsx")
plebiscito.describe
plebiscito
# Out:
#     Idcomuna               Comuna  Total Mesas  Total Electores  \
# 0    13502.0                ALHUE         21.0           6004.0
# 1    13402.0                 BUIN        251.0          73511.0
# 2    13403.0      CALERA DE TANGO         65.0          22016.0
# 3    13102.0            CERRILLOS        205.0          67845.0
# 4    13103.0          CERRO NAVIA        350.0         116544.0
# 5    13301.0               COLINA        258.0          87987.0
# 6    13104.0             CONCHALI        387.0         119859.0
# 7    13503.0             CURACAVI         75.0          25834.0
# 8    13105.0            EL BOSQUE        409.0         138923.0
# 9    13602.0             EL MONTE         80.0          27418.0
# 10   13106.0     ESTACION CENTRAL        396.0         127362.0
# 11   13107.0           HUECHURABA        214.0          72756.0
# 12   13108.0        INDEPENDENCIA        235.0          81550.0
# 13   13603.0        ISLA DE MAIPO         79.0          27290.0
# ...

# %%
plebiscito.columns = plebiscito.columns.str.replace(' ', '')
plebiscito.columns = map(str.lower, plebiscito.columns)
list(plebiscito)
# Out:
# ['idcomuna',
#  'comuna',
#  'totalmesas',
#  'totalelectores',
#  'totalvotacion',
#  'apruebo',
#  'rechazo',
#  'personaspobrezaingresos',
#  'porcpobrezaingresos',
#  'ingresopromedio',
#  'ingresosmunicipalespc']

# %%
plebiscito = plebiscito.dropna(how='all')

# %%
from scipy import stats
import numpy as np

y=plebiscito.apruebo
x=plebiscito.ingresopromedio

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)

print(slope, p_value)
# Out:
# 0.01313600216626408 0.5156705441104303

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_linear_regression

intercept, slope, corr_coeff = plot_linear_regression(x, y)
plt.show()
# Out:
# /home/sebastian/anaconda3/envs/prueba1/lib/python3.8/site-packages/mlxtend/plotting/plot_linear_regression.py:63: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X = X[:, np.newaxis]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-1108444290a2> in <module>
#       2 from mlxtend.plotting import plot_linear_regression
#       3
# ----> 4 intercept, slope, corr_coeff = plot_linear_regression(x, y)
#       5 plt.show()
#
# ~/anaconda3/envs/prueba1/lib/python3.8/site-packages/mlxtend/plotting/plot_linear_regression.py in plot_linear_regression(X, y, model, corr_func, scattercolor, fit_style, legend, xlim)
#      75         x_min, x_max = xlim
#      76
# ---> 77     y_min = model.predict(x_min)
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


sns.regplot(x, y)
# Out:
# /home/sebastian/anaconda3/envs/prueba1/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ingresopromedio', ylabel='apruebo'>

# %%
sns.lmplot(x, y)
# Out:
# /home/sebastian/anaconda3/envs/prueba1/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-e787e6bb2080> in <module>
# ----> 1 sns.lmplot(x, y)
#
# ~/anaconda3/envs/prueba1/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
